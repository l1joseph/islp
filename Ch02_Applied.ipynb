# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

# %%
college = pd.read_csv('College.csv')

# %%
college
# Out:
#                          Unnamed: 0 Private   Apps  Accept  Enroll  Top10perc  \
# 0      Abilene Christian University     Yes   1660    1232     721         23
# 1                Adelphi University     Yes   2186    1924     512         16
# 2                    Adrian College     Yes   1428    1097     336         22
# 3               Agnes Scott College     Yes    417     349     137         60
# 4         Alaska Pacific University     Yes    193     146      55         16
# ..                              ...     ...    ...     ...     ...        ...
# 772         Worcester State College      No   2197    1515     543          4
# 773               Xavier University     Yes   1959    1805     695         24
# 774  Xavier University of Louisiana     Yes   2097    1915     695         34
# 775                 Yale University     Yes  10705    2453    1317         95
# 776    York College of Pennsylvania     Yes   2989    1855     691         28
#
# ...

# %%
college2 = pd.read_csv('College.csv', index_col=0)
college3 = college.rename({'Unnamed: 0':'College'}, axis= 1)
college3 = college3.set_index('College')

# %%
college3
# Out:
#                                Private   Apps  Accept  Enroll  Top10perc  \
# College
# Abilene Christian University       Yes   1660    1232     721         23
# Adelphi University                 Yes   2186    1924     512         16
# Adrian College                     Yes   1428    1097     336         22
# Agnes Scott College                Yes    417     349     137         60
# Alaska Pacific University          Yes    193     146      55         16
# ...                                ...    ...     ...     ...        ...
# Worcester State College             No   2197    1515     543          4
# Xavier University                  Yes   1959    1805     695         24
# Xavier University of Louisiana     Yes   2097    1915     695         34
# Yale University                    Yes  10705    2453    1317         95
# York College of Pennsylvania       Yes   2989    1855     691         28
#
#                                 Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# ...

# %%
college = college3

# %%
college.describe()
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %%
college[['Apps', 'Accept']].describe()
# Out:
#                Apps        Accept
# count    777.000000    777.000000
# mean    3001.638353   2018.804376
# std     3870.201484   2451.113971
# min       81.000000     72.000000
# 25%      776.000000    604.000000
# 50%     1558.000000   1110.000000
# 75%     3624.000000   2424.000000
# max    48094.000000  26330.000000

# %%
pd.plotting.scatter_matrix(college[['Top10perc', 'Apps', 'Enroll']]);

# %%
fig, ax = subplots(figsize=(8, 8))
college.boxplot('Outstate', by='Private', ax=ax);
ax.set_title('Box Plot of Outstate by Private')
ax.set_xlabel('Outstate')
ax.set_ylabel('Private')
# Out:
# Text(0, 0.5, 'Private')

# %%
sns.boxplot(x = college['Outstate'], y = college['Private']);

# %%
# college['Elite'] = pd.cut(college['Top10perc'], [0,0.5,1],
# labels=['No', 'Yes'])
college['Elite'] = np.where(college['Top10perc'] > 50,'Yes','No')
college
# Out:
#                                Private   Apps  Accept  Enroll  Top10perc  \
# College
# Abilene Christian University       Yes   1660    1232     721         23
# Adelphi University                 Yes   2186    1924     512         16
# Adrian College                     Yes   1428    1097     336         22
# Agnes Scott College                Yes    417     349     137         60
# Alaska Pacific University          Yes    193     146      55         16
# ...                                ...    ...     ...     ...        ...
# Worcester State College             No   2197    1515     543          4
# Xavier University                  Yes   1959    1805     695         24
# Xavier University of Louisiana     Yes   2097    1915     695         34
# Yale University                    Yes  10705    2453    1317         95
# York College of Pennsylvania       Yes   2989    1855     691         28
#
#                                 Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# ...

# %%
college['Elite'].value_counts()
# Out:
# No     699
# Yes     78
# Name: Elite, dtype: int64

# %%
fig, ax = subplots(figsize=(8, 8))
college.boxplot('Outstate', by='Elite', ax=ax);
ax.set_title('Box Plot of Outstate by Elite')
ax.set_xlabel('Outstate')
ax.set_ylabel('Elite')
# Out:
# Text(0, 0.5, 'Elite')

# %%
sns.boxplot(x = college['Outstate'], y = college['Elite']);

# %%
# we need to plot by first dividing some of the features into bins  andt then plotting the same
# the features used are ['Enroll','Phd','Termainal']

college['Enroll'] = pd.cut(college['Enroll'],bins=3,labels = ['Low','Medium','High'])
college['PhD'] = pd.cut(college['PhD'],bins = 5,labels = ['Very low','Low','Medium','High','Very High'])
college['Terminal'] = pd.cut(college['Terminal'],bins = 4,labels = ['Very low','Low','High','Very High'])
college['Accept'] = pd.cut(college['Accept'], bins = 3, labels = ['Low', 'Medium', 'High'])

# %%
fig = plt.figure()

plt.subplot(2,2,1)
college['Enroll'].value_counts().plot.bar(title = 'Enroll')

plt.subplot(2,2,2)
college['PhD'].value_counts().plot.bar(title = 'PhD')

plt.subplot(2,2,3)
college['Terminal'].value_counts().plot.bar(title = 'Terminal')

plt.subplot(2,2,4)
college['Accept'].value_counts().plot.bar(title = 'Accept')

#to add space in between the subplots
fig.subplots_adjust(hspace=1)

# %%
Auto = pd.read_csv('Auto.csv')
Auto_new = Auto.dropna()
Auto = Auto_new
Auto = Auto.set_index('name')

# %%
Auto
#Quantitative: mpg, cylinders, displacement, horsepower, weight, acceleration, year
#Qualitative: origin, name
# Out:
#                             mpg  cylinders  displacement  horsepower  weight  \
# name
# chevrolet chevelle malibu  18.0          8         307.0         130    3504
# buick skylark 320          15.0          8         350.0         165    3693
# plymouth satellite         18.0          8         318.0         150    3436
# amc rebel sst              16.0          8         304.0         150    3433
# ford torino                17.0          8         302.0         140    3449
# ...                         ...        ...           ...         ...     ...
# ford mustang gl            27.0          4         140.0          86    2790
# vw pickup                  44.0          4          97.0          52    2130
# dodge rampage              32.0          4         135.0          84    2295
# ford ranger                28.0          4         120.0          79    2625
# chevy s-10                 31.0          4         119.0          82    2720
#
# ...

# %%
info = Auto.describe().T
info['range']= info['max']- info['min']
info = info[['range', 'mean', 'std']]
info.T
# Out:
#              mpg  cylinders  displacement  horsepower       weight  \
# range  37.600000   5.000000    387.000000  184.000000  3527.000000
# mean   23.445918   5.471939    194.411990  104.469388  2977.584184
# std     7.805007   1.705783    104.644004   38.491160   849.402560
#
#        acceleration       year    origin
# range     16.800000  12.000000  2.000000
# mean      15.541327  75.979592  1.576531
# std        2.758864   3.683737  0.805518

# %%
info = Auto.drop(Auto.index[10:85]).describe().T
info['range']= info['max']- info['min']
info = info[['range', 'mean', 'std']]
info.T
# Out:
#              mpg  cylinders  displacement  horsepower       weight  \
# range  35.600000   5.000000    387.000000  184.000000  3197.000000
# mean   25.006028   5.283688    180.120567   99.039007  2884.939716
# std     7.921384   1.637315     96.164263   34.197280   793.236373
#
#        acceleration       year    origin
# range     16.100000  12.000000  2.000000
# mean      15.713121  77.482270  1.631206
# std        2.601575   3.017394  0.830138

# %%
sns.pairplot(Auto)
# Out:
# /opt/homebrew/Caskroom/miniconda/base/envs/islp/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# we can see from the above graph that the features, displacement, horepower and weight are somewhat linearly realted.
# as these features increases, the value of mpg decreases, the same can be said with attributes like cylinder count

# discrete feature like origin and year, also show some kind of trend with mpg.

# %%
boston = pd.read_csv('Boston.csv')
boston
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
print('number of rows',boston.shape[0])
print('number of cols',boston.shape[1])
# Out:
# number of rows 506
# number of cols 14

# %%
sns.pairplot(boston)
sns.set(font_scale= 4)
# Out:
# /opt/homebrew/Caskroom/miniconda/base/envs/islp/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
corr_matrix = boston.corr()
corr_matrix.iloc[1:,0].sort_values()
# Out:
# medv      -0.388305
# black     -0.385064
# dis       -0.379670
# rm        -0.219247
# zn        -0.200469
# chas      -0.055892
# ptratio    0.289946
# age        0.352734
# indus      0.406583
# nox        0.420972
# lstat      0.455621
# tax        0.582764
# rad        0.625505
# Name: crim, dtype: float64

# %%
#through the above table we can conclue that medv, black, TAX, and RAD are highly realted to CRIM.
#TAX, RAD are positively correlated, whereas medv,black are negatively correlated

# %%
boston.sort_values(by= ['crim','tax','ptratio'],ascending=False).head().index
# Out:
# Int64Index([380, 418, 405, 410, 414], dtype='int64')

# %%
charles =len(boston[boston['chas'] == 1])
print('Number of suburbs near Charles river: ' + str(charles))
print(charles/len(boston))
# Out:
# Number of suburbs near Charles river: 35
# 0.0691699604743083

# %%
boston['ptratio'].median()
# Out:
# 19.05

# %%
boston[boston['medv'] == boston['medv'].min()].head(1)
# Out:
#         crim   zn  indus  chas    nox     rm    age     dis  rad  tax  \
# 398  38.3518  0.0   18.1     0  0.693  5.453  100.0  1.4896   24  666
#
#      ptratio  black  lstat  medv
# 398     20.2  396.9  30.59   5.0

# %%
info = boston.describe().T
info = info[['mean', '25%', '50%', '75%']]
info.T
# Out:
#           crim         zn      indus     chas       nox        rm        age  \
# mean  3.613524  11.363636  11.136779  0.06917  0.554695  6.284634  68.574901
# 25%   0.082045   0.000000   5.190000  0.00000  0.449000  5.885500  45.025000
# 50%   0.256510   0.000000   9.690000  0.00000  0.538000  6.208500  77.500000
# 75%   3.677083  12.500000  18.100000  0.00000  0.624000  6.623500  94.075000
#
#            dis        rad         tax    ptratio       black      lstat  \
# mean  3.795043   9.549407  408.237154  18.455534  356.674032  12.653063
# 25%   2.100175   4.000000  279.000000  17.400000  375.377500   6.950000
# 50%   3.207450   5.000000  330.000000  19.050000  391.440000  11.360000
# 75%   5.188425  24.000000  666.000000  20.200000  396.225000  16.955000
#
#            medv
# mean  22.532806
# 25%   17.025000
# 50%   21.200000
# 75%   25.000000

# %%
def rooms (num):
    room = len(boston[boston['rm']>= num])
    return room
print('More than 7 rooms per dwelling: ' + str(rooms(7)))
print('More than 8 rooms per dwelling: ' + str(rooms(8)))
# Out:
# More than 7 rooms per dwelling: 64
# More than 7 rooms per dwelling: 13

# %%
info = boston[boston['rm']>8].describe().T
info = info[['mean','25%','50%','75%']]
info.T
# Out:
#           crim         zn     indus      chas       nox        rm        age  \
# mean  0.718795  13.615385  7.078462  0.153846  0.539238  8.348538  71.538462
# 25%   0.331470   0.000000  3.970000  0.000000  0.504000  8.247000  70.400000
# 50%   0.520140   0.000000  6.200000  0.000000  0.507000  8.297000  78.300000
# 75%   0.578340  20.000000  6.200000  0.000000  0.605000  8.398000  86.500000
#
#            dis       rad         tax    ptratio       black  lstat  medv
# mean  3.430192  7.461538  325.076923  16.361538  385.210769   4.31  44.2
# 25%   2.288500  5.000000  264.000000  14.700000  384.540000   3.32  41.7
# 50%   2.894400  7.000000  307.000000  17.400000  386.860000   4.14  48.3
# 75%   3.651900  8.000000  307.000000  17.400000  389.700000   5.12  50.0

# %%
info = boston.describe().T
info = info[['mean','25%','50%','75%']]
info.T
# Out:
#           crim         zn      indus     chas       nox        rm        age  \
# mean  3.613524  11.363636  11.136779  0.06917  0.554695  6.284634  68.574901
# 25%   0.082045   0.000000   5.190000  0.00000  0.449000  5.885500  45.025000
# 50%   0.256510   0.000000   9.690000  0.00000  0.538000  6.208500  77.500000
# 75%   3.677083  12.500000  18.100000  0.00000  0.624000  6.623500  94.075000
#
#            dis        rad         tax    ptratio       black      lstat  \
# mean  3.795043   9.549407  408.237154  18.455534  356.674032  12.653063
# 25%   2.100175   4.000000  279.000000  17.400000  375.377500   6.950000
# 50%   3.207450   5.000000  330.000000  19.050000  391.440000  11.360000
# 75%   5.188425  24.000000  666.000000  20.200000  396.225000  16.955000
#
#            medv
# mean  22.532806
# 25%   17.025000
# 50%   21.200000
# 75%   25.000000

# %%
# we can conclude that suburbs having more than 8 rooms per dwelling have much lower crime rater (crim) values. Also, these have
# less value of lstat, and their median value, price is signifanctly larger(approx double) than the overall mean price of rooms in boston as a whole
